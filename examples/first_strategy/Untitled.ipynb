# %%
import pandas as pd

# %%
df = pd.read_csv('day.csv')

# %%
df
# Out:
#       trade_date
# 0     1990-12-19
# 1     1990-12-20
# 2     1990-12-21
# 3     1990-12-24
# 4     1990-12-25
# ...          ...
# 7823  2022-12-26
# 7824  2022-12-27
# 7825  2022-12-28
# 7826  2022-12-29
# 7827  2022-12-30
#
# [7828 rows x 1 columns]

# %%
res = open('day.txt').read().strip().split('\n')

# %%
res[-1]
# Out:
# '2022-08-18'

# %%
res2 = df[df['trade_date'] < '2022-08-18']['trade_date'].to_list()

# %%
for i in res:
    if i not in res2:
        print(i)
# Out:
# 1991-01-05
# 1991-01-12
# 1991-01-19
# 1991-01-26
# 1991-02-02
# 1991-02-09
# 1991-02-23
# 1991-03-02
# 1991-03-09
# 1991-03-16
# 1991-03-23
# 1991-03-30
# 1991-04-06
# 1991-04-13
# 1991-04-20
# 1991-05-04
# 1991-05-11
# 1991-05-18
# 1991-05-25
# 1991-06-01
# 1991-06-08
# 1991-06-15
# 1991-06-22
# 1991-06-29
# 1991-07-06
# 1991-07-13
# 1991-07-20
# 1991-07-27
# 1991-08-03
# 1991-08-17
# 1991-08-24
# 1991-08-31
# 1991-09-07
# 1991-09-14
# 1991-09-21
# 1991-09-28
# 1991-09-29
# 1991-10-05
# 1991-10-12
# 1991-10-19
# 1991-10-26
# 1991-11-02
# 1991-11-09
# 1991-11-16
# 1991-11-17
# 1991-11-23
# 1991-11-30
# 1991-12-07
# 1991-12-14
# 1991-12-21
# 1991-12-28
# 1992-02-01
# 1992-02-02
# 1992-04-18
# 1992-05-03
# 1992-10-04
# 1992-12-20
# 1993-01-03
# 1993-05-01
# 1993-05-02
# 1998-06-20
# 2022-08-18

# %%
res
# Out:
# ['1990-12-19',
#  '1990-12-20',
#  '1990-12-21',
#  '1990-12-24',
#  '1990-12-25',
#  '1990-12-26',
#  '1990-12-27',
#  '1990-12-28',
#  '1990-12-31',
#  '1991-01-02',
#  '1991-01-03',
#  '1991-01-04',
#  '1991-01-05',
#  '1991-01-07',
#  '1991-01-08',
#  '1991-01-09',
#  '1991-01-10',
#  '1991-01-11',
#  '1991-01-12',
#  '1991-01-14',
#  '1991-01-15',
#  '1991-01-16',
#  '1991-01-17',
#  '1991-01-18',
#  '1991-01-19',
#  '1991-01-21',
#  '1991-01-22',
#  '1991-01-23',
#  '1991-01-24',
#  '1991-01-25',
#  '1991-01-26',
#  '1991-01-28',
#  '1991-01-29',
#  '1991-01-30',
#  '1991-01-31',
#  '1991-02-01',
#  '1991-02-02',
#  '1991-02-04',
#  '1991-02-05',
#  '1991-02-06',
#  '1991-02-07',
#  '1991-02-08',
#  '1991-02-09',
#  '1991-02-11',
#  '1991-02-12',
#  '1991-02-13',
#  '1991-02-14',
#  '1991-02-19',
#  '1991-02-20',
#  '1991-02-21',
#  '1991-02-22',
#  '1991-02-23',
#  '1991-02-25',
#  '1991-02-26',
#  '1991-02-27',
#  '1991-02-28',
#  '1991-03-01',
#  '1991-03-02',
# ...
